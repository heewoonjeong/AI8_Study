# %% [markdown]
# # chap7.모듈

# %%
# 모듈을 프로그램에 삽입 import 모듈명 -> 모듈명 .함수 또는 모듈명. 변수
import math

print(math.ceil(43.2)) # 올림정수 44
print(math.floor(43.2)) # 내림정수 43
print(math.sin(1))
print(round(43.6))
# Out:
# 44
# 43
# 0.8414709848078965
# 44

# %%
# 모듈명이 길어서 약어로 축약해서 사용하고자 할 경우 
import math as m 
print(m.ceil(43.2)) # 올림정수 44
print(m.floor(43.2)) # 내림정수 43
print(m.sin(1))
# Out:
# 44
# 43
# 0.8414709848078965

# %%
from math import sin, cos, floor, ceil 

print(m.ceil(43.2)) # 올림정수 44
print(m.floor(43.2)) # 내림정수 43
print(m.sin(1))
# Out:
# 44
# 43
# 0.8414709848078965

# %%
import random
print ("# random 모듈")

# random(): 0.0 <= x < 1.0 사이의 float를 리턴합니다. 
print("- random():", random.random())

#uniform(min, max): 지정한 범위 사이의 float를 리턴합니다. 
print("- uniform(10, 20):", random.uniform(10, 20))

# randrange() : 지정한 범위의int를 리턴합니다.
# - randrange(max) : 0부터 max 사이의 값을 리턴합니다.
# - randrange(min, max): min max 사이의 값을 리턴합니다. 

print("- randrange(10):", random.randrange(10))

# choice(list) :리스트 내부에 있는 요소를 랜던하게 선택합니다 
print("- choice([1, 2, 3, 4, 5]):", random.choice([1, 2, 3, 4, 5]))

# shuffle(list) :리스트의 요소들을 랜덤하게 썩습니다. 
print("- ):", )

# sample(list, k=<숫자>): 리스트의 요소중에 k를 뽑습니다. 
print("- :", )
# Out:
# # random 모듈
# - random(): 0.5129880592462465
# - uniform(10, 20): 15.60207662354178
# - randrange(10): 6
# - choice([1, 2, 3, 4, 5]): 2
# - ):
# - :

# %%
# os module 
import os 

print("현재 운영체제 : ", os.name)
print("현재 폴더 : ", os.getcwd())
print("현재 폴더 리스트 :" ,os.listdir())

#!dir -> !운영체제 명령어 실행
# Out:
# 현재 운영체제 :  nt
# 현재 폴더 :  C:\Users\hura3\python-src
# 현재 폴더 리스트 : ['.ipynb_checkpoints', '2.ipynb', '4.ipynb', 'beautiful_flask.py', 'dataset', 'day-4 module.ipynb', 'day-9.ipynb', 'Flask_basic-Copy1.ipynb', 'Flask_basic.py', 'module_basic', 'python 계산식프로그램.ipynb', 'python- naver_move_ranking.ipynb', 'python- naver_papago.ipynb', 'python-학생,성적구하기.ipynb', 'python.Q 150~215.ipynb', 'python.Q 228~270.ipynb', 'python1-자료,숫자,문자열.ipynb', 'python2-문자열,조건문, if~else,elif 반복문.ipynb', 'python3-딕셔너리 반복문.ipynb', 'python5- class 함수.ipynb', 'test_dir', 'test_package', '__pycache__']

# %%
# 디렉토리 생성 : mkdir() 
# 디렉토리 삭제 : rmdir()
os.mkdir('test_dir')
print("현재 폴더 리스트:",os.listdir())
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 # 디렉토리 생성 : mkdir()
#       2 # 디렉토리 삭제 : rmdir()
# ----> 3 os.mkdir('test_dir')
#       4 print("현재 폴더 리스트:",os.listdir())
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'test_dir'

# %%
# 파일 삭제 os.remove(파일명)
os.remove('ubtutile.ipynb')
os.remove('ubtutile1.ipynb')
print("현재 폴더 리스트:",os.listdir())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # 파일 삭제 os.remove(파일명)
# ----> 2 os.remove('ubtutile.ipynb')
#       3 os.remove('ubtutile1.ipynb')
#       4 print("현재 폴더 리스트:",os.listdir())
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: 'ubtutile.ipynb'

# %%
# 파일명 변경 : rename(old_name , new_name)
os.rename('list.txt', 'rename.txt')
print(" 현재 폴터 리스트:", os.listdir())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # 파일명 변경 : rename(old_name , new_name)
# ----> 2 os.rename('list.txt', 'rename.txt')
#       3 print(" 현재 폴터 리스트:", os.listdir())
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: 'list.txt' -> 'rename.txt'

# %%
import time

print('111')
time.sleep(3)
print('222')
# Out:
# 111
# 222

# %%
# urllib 모듈 : URL(uniform resorce locator) 을 다루는 모듈 
from urllib import request 

target = request.urlopen('https://www.naver.com/') # url 주소 연결
output = target.read() #binary 의 한 문장으로 자료를 가져옴

output
# Out:
# b'\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\x
# ...

# %% [markdown]
# # 7-2 외부모듈

# %%
target = request.urlopen('https://www.naver.com/') # url 주소 연결
output = target.read() #binary 의 한 문장으로 자료를 가져옴

soup = BeautifulSoup(output)
soup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       1 target = request.urlopen('https://www.naver.com/') # url 주소 연결
#       2 output = target.read() #binary 의 한 문장으로 자료를 가져옴
# ----> 4 soup = BeautifulSoup(output)
#       5 soup
#
# NameError: name 'BeautifulSoup' is not defined

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(output)
soup
